# %%
print("welcome to Notebook")
# Out:
# welcome to Notebook

# %%
import pandas as pd

# %%
dataset=pd.read_csv('crop.csv')
dataset
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
dataset.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
dataset.head(25)
# Out:
#      N   P   K  temperature   humidity        ph    rainfall label
# 0   90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1   85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2   60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3   74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4   78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# 5   69  37  42    23.058049  83.370118  7.073454  251.055000  rice
# 6   69  55  38    22.708838  82.639414  5.700806  271.324860  rice
# 7   94  53  40    20.277744  82.894086  5.718627  241.974195  rice
# 8   89  54  38    24.515881  83.535216  6.685346  230.446236  rice
# 9   68  58  38    23.223974  83.033227  6.336254  221.209196  rice
# 10  91  53  40    26.527235  81.417538  5.386168  264.614870  rice
# 11  90  46  42    23.978982  81.450616  7.502834  250.083234  rice
# 12  78  58  44    26.800796  80.886848  5.108682  284.436457  rice
# ...

# %%
dataset.head(-2)
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2193  116  38  34    23.292503  50.045570  6.020947  183.468585  coffee
# 2194   97  35  26    24.914610  53.741447  6.334610  166.254931  coffee
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
#
# [2198 rows x 8 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
dataset.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
x=dataset.iloc[:,[0,1,2,3,4,5,6]].values

# %%
x[0]
# Out:
# array([ 90.        ,  42.        ,  43.        ,  20.87974371,
#         82.00274423,   6.50298529, 202.9355362 ])

# %%
x[5]
# Out:
# array([ 69.        ,  37.        ,  42.        ,  23.05804872,
#         83.37011772,   7.0734535 , 251.0549998 ])

# %%
len(x)
# Out:
# 2200

# %%
y=dataset.iloc[:,[7]].values

# %%
y[0]
# Out:
# array(['rice'], dtype=object)

# %%
len(y)
# Out:
# 2200

# %%
y[0]
# Out:
# array(['rice'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
print(xtrain[0],len(xtrain))
# Out:
# [131.          60.          17.          25.32023717  81.79475917
#    7.42504132  83.46532547] 1760

# %%
print(xtest[0],len(xtest))
# Out:
# [ 59.          62.          52.          43.67549305  93.10887229
#    6.60866768 103.8235658 ] 440

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier()

# %%
import numpy as np
ytrain=np.ravel(ytrain)
model.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
testdata=np.array([[10,71,18,19.54284889,66.34777265,6.151029296,173.11069819999997]])

# %%
result=model.predict(testdata)
result
# Out:
# array(['pigeonpeas'], dtype=object)

# %%
ypred=model.predict(xtest)

# %%
print(ypred)
# Out:
# ['papaya' 'papaya' 'pomegranate' 'cotton' 'jute' 'maize' 'muskmelon'
#  'rice' 'mungbean' 'kidneybeans' 'banana' 'pomegranate' 'papaya' 'mango'
#  'coffee' 'mothbeans' 'pigeonpeas' 'cotton' 'papaya' 'lentil' 'coconut'
#  'cotton' 'mango' 'mango' 'mungbean' 'cotton' 'apple' 'papaya' 'blackgram'
#  'mothbeans' 'cotton' 'coffee' 'kidneybeans' 'mango' 'banana' 'muskmelon'
#  'cotton' 'papaya' 'watermelon' 'kidneybeans' 'jute' 'blackgram' 'maize'
#  'jute' 'apple' 'blackgram' 'maize' 'cotton' 'mothbeans' 'pigeonpeas'
#  'grapes' 'kidneybeans' 'mothbeans' 'kidneybeans' 'mothbeans' 'orange'
#  'jute' 'orange' 'kidneybeans' 'banana' 'maize' 'blackgram' 'maize'
#  'grapes' 'lentil' 'pomegranate' 'kidneybeans' 'grapes' 'orange'
#  'kidneybeans' 'pomegranate' 'grapes' 'jute' 'watermelon' 'blackgram'
#  'kidneybeans' 'jute' 'coffee' 'mungbean' 'grapes' 'cotton' 'apple'
#  'kidneybeans' 'apple' 'muskmelon' 'pomegranate' 'papaya' 'coffee'
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(ytest,ypred)
score*100
# Out:
# 97.72727272727273

# %%
import joblib
joblib.dump(model,"knncropmodel.pkl")
# Out:
# ['knncropmodel.pkl']
